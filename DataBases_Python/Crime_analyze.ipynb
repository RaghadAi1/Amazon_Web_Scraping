# %% [markdown]
# # Goal:
# - Analyze and visualize crime in Los Angeles data to understand patterns, identify trends, and make informed decisions based on the data.

# %%
# !pip install ipython-sql prettytable
# !pip install ipython-sql

# Import the 'prettytable' library, which is used to display data in a formatted table
import prettytable

# Set the default display format for prettytable to 'DEFAULT' (i.e., a simple table format)
prettytable.DEFAULT = 'DEFAULT'

# %%
# connection
import mysql.connector,sqlite3,pandas as pd,seaborn as sns ,matplotlib.pyplot as plt
# %reload_ext sql
# %sql sqlite:///Crime_analyze.db

conn=sqlite3.connect("Crime_analyze.db")
cursor=conn.cursor()

# read=pd.read_csv("Crime_Data_2010_2017.csv")
# load as table and give it a name
# read.to_sql("Crime_analyze_table",conn)
df=pd.read_sql("select*from Crime_analyze_table",conn)

# %%
df
# Out:
#            index  DR Number Date Reported Date Occurred  Time Occurred  \
# 0              0    1208575    03/14/2013    03/11/2013           1800
# 1              1  102005556    01/25/2010    01/22/2010           2300
# 2              2        418    03/19/2013    03/18/2013           2030
# 3              3  101822289    11/11/2010    11/10/2010           1800
# 4              4   42104479    01/11/2014    01/04/2014           2300
# ...          ...        ...           ...           ...            ...
# 1584311  1584311  172116482    09/07/2017    09/07/2017           1005
# 1584312  1584312  172116489    09/07/2017    09/07/2017           1200
# 1584313  1584313  172116491    08/30/2017    07/15/2017              1
# 1584314  1584314  172116498    09/08/2017    09/08/2017           1845
# 1584315  1584315  172116510    09/08/2017    07/12/2017           2230
#
#          Area ID    Area Name  Reporting District  Crime Code  \
# 0             12  77th Street                1241         626
# 1             20      Olympic                2071         510
# 2             18    Southeast                1823         510
# 3             18    Southeast                1803         510
# 4             21      Topanga                2133         745
# ...          ...          ...                 ...         ...
# 1584311       21      Topanga                2141         440
# 1584312       21      Topanga                2156         330
# 1584313       21      Topanga                2147         649
# 1584314       21      Topanga                2136         946
# 1584315       21      Topanga                2105         236
#
#                            Crime Code Description  ...  \
# 0               INTIMATE PARTNER - SIMPLE ASSAULT  ...
# 1                                VEHICLE - STOLEN  ...
# 2                                VEHICLE - STOLEN  ...
# 3                                VEHICLE - STOLEN  ...
# 4        VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...
# ...                                           ...  ...
# 1584311        THEFT PLAIN - PETTY ($950 & UNDER)  ...
# 1584312                     BURGLARY FROM VEHICLE  ...
# 1584313          DOCUMENT FORGERY / STOLEN FELONY  ...
# 1584314                 OTHER MISCELLANEOUS CRIME  ...
# 1584315     INTIMATE PARTNER - AGGRAVATED ASSAULT  ...
#
#                                      Weapon Description  Status Code  \
# 0        STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)           AO
# 1                                                  None           IC
# 2                                                  None           IC
# 3                                                  None           IC
# 4                                                  None           IC
# ...                                                 ...          ...
# 1584311                                            None           IC
# 1584312                                            None           IC
# 1584313                                            None           IC
# 1584314                                            None           IC
# 1584315  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)           IC
#
#         Status Description Crime Code 1  Crime Code 2 Crime Code 3  \
# 0              Adult Other        626.0           NaN          NaN
# 1              Invest Cont        510.0           NaN          NaN
# 2              Invest Cont        510.0           NaN          NaN
# 3              Invest Cont        510.0           NaN          NaN
# 4              Invest Cont        745.0           NaN          NaN
# ...                    ...          ...           ...          ...
# 1584311        Invest Cont        440.0           NaN          NaN
# 1584312        Invest Cont        330.0           NaN          NaN
# 1584313        Invest Cont        649.0           NaN          NaN
# 1584314        Invest Cont        946.0         998.0          NaN
# 1584315        Invest Cont        236.0           NaN          NaN
#
#          Crime Code 4                                   Address Cross Street  \
# 0                 NaN   6300    BRYNHURST                    AV         None
# 1                 NaN                                  VAN NESS         15TH
# 2                 NaN    200 E  104TH                        ST         None
# 3                 NaN                                      88TH         WALL
# 4                 NaN   7200    CIRRUS                       WY         None
# ...               ...                                       ...          ...
# 1584311           NaN  23800    CALVERT                      ST         None
# 1584312           NaN   6600    TOPANGA CANYON               BL         None
# 1584313           NaN  20900    SHERMAN                      WY         None
# 1584314           NaN                                    REMMET    WYANDOTTE
# 1584315           NaN   8600    INTERNATIONAL                AV         None
#
#                     Location
# 0        (33.9829, -118.3338)
# 1        (34.0454, -118.3157)
# 2         (33.942, -118.2717)
# 3        (33.9572, -118.2717)
# 4        (34.2009, -118.6369)
# ...                       ...
# 1584311  (34.1883, -118.6536)
# 1584312  (34.1905, -118.6059)
# 1584313   (34.201, -118.5885)
# 1584314  (34.2029, -118.6003)
# 1584315  (34.2258, -118.5994)
#
# [1584316 rows x 27 columns]

# %%
# show my data
df.describe(include="all")
# Out:
#                index     DR Number Date Reported Date Occurred  Time Occurred  \
# count   1.584316e+06  1.584316e+06       1584316       1584316   1.584316e+06
# unique           NaN           NaN          2809          2809            NaN
# top              NaN           NaN    08/07/2017    01/01/2010            NaN
# freq             NaN           NaN           804          2135            NaN
# mean    7.921575e+05  1.358072e+08           NaN           NaN   1.363975e+03
# std     4.573528e+05  2.259098e+07           NaN           NaN   6.467544e+02
# min     0.000000e+00  2.100000e+02           NaN           NaN   1.000000e+00
# 25%     3.960788e+05  1.121176e+08           NaN           NaN   9.300000e+02
# 50%     7.921575e+05  1.401095e+08           NaN           NaN   1.430000e+03
# 75%     1.188236e+06  1.520186e+08           NaN           NaN   1.900000e+03
# max     1.584315e+06  9.102204e+08           NaN           NaN   2.359000e+03
#
#              Area ID    Area Name  Reporting District    Crime Code  \
# count   1.584316e+06      1584316        1.584316e+06  1.584316e+06
# unique           NaN           21                 NaN           NaN
# top              NaN  77th Street                 NaN           NaN
# freq             NaN       110605                 NaN           NaN
# mean    1.115232e+01          NaN        1.161595e+03  5.069982e+02
# std     5.986703e+00          NaN        5.986644e+02  2.105490e+02
# min     1.000000e+00          NaN        1.000000e+02  1.100000e+02
# 25%     6.000000e+00          NaN        6.450000e+02  3.300000e+02
# 50%     1.200000e+01          NaN        1.204000e+03  4.400000e+02
# 75%     1.600000e+01          NaN        1.676000e+03  6.260000e+02
# max     2.100000e+01          NaN        2.198000e+03  9.560000e+02
#
#           Crime Code Description  ...  \
# count                    1583904  ...
# unique                       134  ...
# top     BATTERY - SIMPLE ASSAULT  ...
# freq                      145767  ...
# mean                         NaN  ...
# std                          NaN  ...
# min                          NaN  ...
# 25%                          NaN  ...
# 50%                          NaN  ...
# 75%                          NaN  ...
# max                          NaN  ...
#
#                                     Weapon Description  Status Code  \
# count                                           524756      1584314
# unique                                              79            9
# top     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)           IC
# freq                                            319818      1227180
# mean                                               NaN          NaN
# std                                                NaN          NaN
# min                                                NaN          NaN
# 25%                                                NaN          NaN
# 50%                                                NaN          NaN
# 75%                                                NaN          NaN
# max                                                NaN          NaN
#
#        Status Description  Crime Code 1  Crime Code 2 Crime Code 3  \
# count             1584316  1.584309e+06  99997.000000  2183.000000
# unique                  6           NaN           NaN          NaN
# top           Invest Cont           NaN           NaN          NaN
# freq              1227180           NaN           NaN          NaN
# mean                  NaN  5.068795e+02    954.461614   970.715529
# std                   NaN  2.104662e+02    123.611988    88.350046
# min                   NaN  1.100000e+02    121.000000    93.000000
# 25%                   NaN  3.300000e+02    998.000000   998.000000
# 50%                   NaN  4.400000e+02    998.000000   998.000000
# 75%                   NaN  6.260000e+02    998.000000   998.000000
# max                   NaN  9.990000e+02    999.000000   999.000000
#
#         Crime Code 4                          Address Cross Street Location
# count      69.000000                          1584316       262733   1584307
# unique           NaN                            70968        11121     60608
# top              NaN  6TH                          ST     BROADWAY    (0, 0)
# freq             NaN                             3692         4662      5482
# mean      967.173913                              NaN          NaN       NaN
# std        97.571536                              NaN          NaN       NaN
# min       421.000000                              NaN          NaN       NaN
# 25%       998.000000                              NaN          NaN       NaN
# 50%       998.000000                              NaN          NaN       NaN
# 75%       998.000000                              NaN          NaN       NaN
# max       999.000000                              NaN          NaN       NaN
#
# [11 rows x 27 columns]

# %% [markdown]
# # Task 1:
# Most Common Areas for Crime to help law enforcement allocate resources effectively.

# %%
# %sql select "Area Name",count(*) as "crime count"  from Crime_analyze_table  ;
# Out:
#  * sqlite:///Crime_analyze.db
# Done.
# [('77th Street', 1584316)]

# %% [markdown]
# # Task 2:
# Most Common Year for Crime will help with trend analysis and policy recommendations.

# %%
# %sql select strftime('%Y' , "Date Reported") as year from Crime_analyze_table ;
# %sql SELECT DISTINCT "Date Reported" as crime_year,count(*)  as crime_count FROM Crime_analyze_table GROUP BY crime_year ORDER BY crime_count DESC ;
# Out:
#  * sqlite:///Crime_analyze.db
# Done.
# [('08/07/2017', 804),
#  ('07/24/2017', 782),
#  ('07/05/2016', 760),
#  ('07/17/2017', 757),
#  ('05/22/2017', 754),
#  ('06/05/2017', 749),
#  ('08/28/2017', 748),
#  ('01/22/2016', 747),
#  ('10/12/2015', 746),
#  ('01/17/2017', 746),
#  ('11/28/2016', 745),
#  ('07/19/2017', 745),
#  ('06/27/2016', 742),
#  ('09/20/2016', 740),
#  ('07/25/2017', 737),
#  ('07/31/2017', 736),
#  ('06/29/2015', 736),
#  ('08/25/2015', 735),
#  ('08/22/2016', 735),
#  ('11/01/2016', 734),
#  ('10/26/2016', 734),
#  ('10/26/2015', 732),
#  ('07/20/2010', 596),
#  ('05/28/2015', 596),
#  ('05/16/2012', 596),
#  ('05/14/2015', 596),
#  ('05/11/2010', 596),
#  ('05/02/2011', 596),
#  ('04/27/2015', 596),
#  ('04/18/2012', 596),
#  ('03/24/2015', 596),
#  ('03/22/2016', 596),
#  ('03/15/2012', 596),
#  ('01/13/2016', 596),
#  ('01/02/2013', 596),
#  ('10/26/2012', 595),
#  ('09/17/2014', 595),
#  ('08/30/2012', 595),
#  ('08/02/2011', 595),
#  ('07/18/2013', 595),
#  ('07/16/2016', 595),
#  ('07/16/2010', 595),
#  ('04/28/2010', 595),
#  ('04/13/2016', 595),
#  ('03/23/2012', 595),
#  ('02/24/2015', 595),
#  ('01/30/2013', 595),
#  ('01/15/2015', 595),
#  ('12/23/2015', 594),
#  ('09/28/2011', 594),
#  ('09/12/2013', 594),
#  ('07/26/2012', 594),
#  ('07/26/2011', 594),
#  ('07/05/2012', 594),
#  ('04/28/2014', 594),
#  ('03/12/2012', 594),
#  ('03/08/2010', 594),
#  ('02/13/2012', 594),
#  ('01/23/2012', 594),
#  ('01/16/2015', 594),
#  ('01/13/2017', 594),
#  ('11/20/2015', 593),
#  ('11/13/2013', 593),
#  ('10/10/2014', 593),
#  ('09/22/2011', 593),
#  ('09/08/2011', 593),
#  ('08/08/2013', 593),
#  ('06/09/2017', 593),
#  ('05/30/2012', 593),
#  ('05/04/2012', 593),
#  ('04/29/2015', 593),
#  ('04/13/2017', 593),
#  ('04/02/2012', 593),
#  ('03/18/2015', 593),
#  ('03/18/2013', 593),
#  ('03/14/2011', 593),
#  ('10/29/2014', 592),
#  ('10/17/2012', 592),
#  ('08/15/2012', 592),
#  ('07/13/2011', 592),
#  ('06/18/2014', 592),
#  ('06/15/2010', 592),
#  ('06/03/2015', 592),
#  ('05/31/2012', 592),
#  ('05/23/2013', 592),
#  ('05/03/2010', 592),
#  ('04/21/2010', 592),
#  ('03/07/2012', 592),
#  ('01/27/2011', 592),
#  ('10/30/2014', 591),
#  ('10/09/2015', 591),
#  ...]

# %% [markdown]
# # Task 3:
# Find the time difference between the date a crime occurred and the date it was reported.
# - Which day has the most crimes reported or occurred?
# - What is the average delay between "Date Occurred" and "Date Reported"?

# %%
crime=%sql select*from Crime_analyze_table  ;
data3=pd.DataFrame(crime)

data3['Date Occurred'] = pd.to_datetime(data3['Date Occurred'], errors='coerce', format='%m/%d/%Y')
data3['Date Reported'] = pd.to_datetime(data3['Date Reported'], errors='coerce', format='%m/%d/%Y')

# Calculate the difference in the days
data3['Reporting Delay (Days)'] = (data3['Date Reported'] - data3['Date Occurred']).dt.days
sns.histplot(data3['Reporting Delay (Days)'], bins=30, kde=True)
plt.title("Distribution of Reporting Delays")
plt.xlabel("Days to Report")
plt.ylabel("Frequency")
plt.show()
# Out:
#  * sqlite:///Crime_analyze.db
# Done.

# %% [markdown]
# # Task 4:
# Crime Codes that Occur Multiple Times so Filter for crime codes that occur more than once.

# %%
# %sql SELECT "Crime Code"as crime_code, COUNT(*) AS crime_count,"Crime Code Description" FROM Crime_analyze_table GROUP BY crime_code ORDER BY crime_count DESC;
# Out:
#  * sqlite:///Crime_analyze.db
# Done.
# [(624, 145767, 'BATTERY - SIMPLE ASSAULT'),
#  (510, 121329, 'VEHICLE - STOLEN'),
#  (330, 121318, 'BURGLARY FROM VEHICLE'),
#  (310, 114751, 'BURGLARY'),
#  (440, 113709, 'THEFT PLAIN - PETTY ($950 & UNDER)'),
#  (354, 100653, 'THEFT OF IDENTITY'),
#  (626, 85908, 'INTIMATE PARTNER - SIMPLE ASSAULT'),
#  (740, 79433, 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114'),
#  (745, 71523, 'VANDALISM - MISDEAMEANOR ($399 OR UNDER)'),
#  (230, 67631, 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT'),
#  (420, 63995, 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)'),
#  (210, 63408, 'ROBBERY'),
#  (341, 56377, 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036'),
#  (930, 44560, 'CRIMINAL THREATS - NO WEAPON DISPLAYED'),
#  (442, 35032, 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)'),
#  (331, 22588, 'THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)'),
#  (649, 18856, 'DOCUMENT FORGERY / STOLEN FELONY'),
#  (946, 16449, 'OTHER MISCELLANEOUS CRIME'),
#  (956, 16371, 'LETTERS, LEWD'),
#  (900, 16053, 'VIOLATION OF COURT ORDER'),
#  (888, 14303, 'TRESPASSING'),
#  (901, 13481, 'VIOLATION OF RESTRAINING ORDER'),
#  (350, 10326, 'THEFT, PERSON'),
#  (320, 9923, 'BURGLARY, ATTEMPTED'),
#  (220, 9009, 'ATTEMPTED ROBBERY'),
#  (761, 8895, 'BRANDISH WEAPON'),
#  (236, 8629, 'INTIMATE PARTNER - AGGRAVATED ASSAULT'),
#  (480, 8616, 'BIKE - STOLEN'),
#  (860, 8053, 'BATTERY WITH SEXUAL CONTACT'),
#  (121, 7314, 'RAPE, FORCIBLE'),
#  (627, 6779, 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT'),
#  (812, 6431, 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)0060'),
#  (668, 5811, 'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)'),
#  (662, 5100, 'BUNCO, GRAND THEFT'),
#  (237, 4547, 'CHILD NEGLECT (SEE 300 W.I.C.)'),
#  (813, 4185, 'CHILD ANNOYING (17YRS & UNDER)'),
#  (623, 3450, 'BATTERY POLICE (SIMPLE)'),
#  (810, 3438, 'SEX, UNLAWFUL'),
#  (664, 3191, 'BUNCO, PETTY THEFT'),
#  (753, 2824, 'DISCHARGE FIREARMS/SHOTS FIRED'),
#  (886, 2777, 'DISTURBING THE PEACE'),
#  (343, 2673, 'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)'),
#  (648, 2631, 'ARSON'),
#  (437, 2609, 'RESISTING ARREST'),
#  (850, 2578, 'INDECENT EXPOSURE'),
#  (928, 2571, 'THREATENING PHONE CALLS/LETTERS'),
#  (520, 2545, 'VEHICLE - ATTEMPT STOLEN'),
#  (903, 2393, 'CONTEMPT OF COURT'),
#  (410, 2304, 'BURGLARY FROM VEHICLE, ATTEMPTED'),
#  (110, 2155, 'CRIMINAL HOMICIDE'),
#  (251, 2015, 'SHOTS FIRED AT INHABITED DWELLING'),
#  (625, 1808, 'OTHER ASSAULT'),
#  (951, 1709, 'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER'),
#  (910, 1657, 'KIDNAPPING'),
#  (940, 1600, 'EXTORTION'),
#  (815, 1568, 'SEXUAL PENTRATION WITH A FOREIGN OBJECT'),
#  (763, 1480, 'STALKING'),
#  (441, 1311, 'THEFT PLAIN - ATTEMPT'),
#  (235, 1295, 'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT'),
#  (231, 1258, 'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER'),
#  (820, 1254, 'ORAL COPULATION'),
#  (647, 1157, 'THROWING OBJECT AT MOVING VEHICLE'),
#  (943, 1125, 'CRUELTY TO ANIMALS'),
#  (902, 1020, 'VIOLATION OF TEMPORARY RESTRAINING ORDER'),
#  (821, 1000, 'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02'),
#  (351, 968, 'PURSE SNATCHING'),
#  (661, 962, 'UNAUTHORIZED COMPUTER ACCESS'),
#  (762, 958, 'LEWD CONDUCT'),
#  (421, 934, 'THEFT FROM MOTOR VEHICLE - ATTEMPT'),
#  (922, 915, 'CHILD STEALING'),
#  (932, 880, 'PEEPING TOM'),
#  (122, 871, 'RAPE, ATTEMPTED'),
#  (755, 857, 'BOMB SCARE'),
#  (933, 727, 'PROWLER'),
#  (434, 718, 'FALSE IMPRISONMENT'),
#  (660, 700, 'COUNTERFEIT'),
#  (653, 661, 'CREDIT CARDS, FRAUD USE ($950.01 & OVER)'),
#  (920, 586, 'KIDNAPPING - GRAND ATTEMPT'),
#  (352, 565, 'PICKPOCKET'),
#  (670, 462, 'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)'),
#  (666, 444, 'BUNCO, ATTEMPT'),
#  (805, 413, 'PIMPING'),
#  (949, 392, 'ILLEGAL DUMPING'),
#  (433, 371, 'DRIVING WITHOUT OWNER CONSENT (DWOC)'),
#  (439, 310, 'FALSE POLICE REPORT'),
#  (651, 266, 'DOCUMENT WORTHLESS ($200.01 & OVER)'),
#  (890, 249, 'FAILURE TO YIELD'),
#  (487, 227, 'BOAT - STOLEN'),
#  (622, 223, 'BATTERY ON A FIREFIGHTER'),
#  (450, 223, 'THEFT FROM PERSON - ATTEMPT'),
#  (806, 195, 'PANDERING'),
#  (822, 186, None),
#  (654, 186, 'CREDIT CARDS, FRAUD USE ($950 & UNDER'),
#  (438, 178, 'RECKLESS DRIVING'),
#  (250, 178, 'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT'),
#  (950, 170, 'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $400'),
#  (474, 168, 'THEFT, COIN MACHINE - PETTY ($950 & UNDER)'),
#  (443, 154, 'SHOPLIFTING - ATTEMPT'),
#  (954, 149, 'CONTRIBUTING'),
#  (756, 134, 'WEAPONS POSSESSION/BOMBING'),
#  (345, 125, 'DISHONEST EMPLOYEE - GRAND THEFT'),
#  (444, 100, 'DISHONEST EMPLOYEE - PETTY THEFT'),
#  (760, 90, None),
#  (814, 86, None),
#  (870, 70, 'CHILD ABANDONMENT'),
#  (471, 64, 'TILL TAP - PETTY ($950 & UNDER)'),
#  (347, 63, 'GRAND THEFT / INSURANCE FRAUD'),
#  (921, 50, None),
#  (944, 46, 'CONSPIRACY'),
#  (451, 40, 'PURSE SNATCHING - ATTEMPT'),
#  (652, 39, 'DOCUMENT WORTHLESS ($200 & UNDER)'),
#  (435, 39, 'LYNCHING'),
#  (865, 37, 'DRUGS, TO A MINOR'),
#  (924, 34, 'TELEPHONE PROPERTY - DAMAGE'),
#  (880, 34, 'DISRUPT SCHOOL'),
#  (473, 33, 'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)'),
#  (942, 29, 'BRIBERY'),
#  (485, 27, 'BIKE - ATTEMPTED STOLEN'),
#  (353, 26, 'DRUNK ROLL'),
#  (436, 20, 'LYNCHING - ATTEMPTED'),
#  (840, 19, 'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM0065'),
#  (446, 19, 'PETTY THEFT - AUTO REPAIR'),
#  (884, 18, 'FAILURE TO DISPERSE'),
#  (931, 17, 'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)0132'),
#  (475, 17, 'THEFT, COIN MACHINE - ATTEMPT'),
#  (452, 15, 'PICKPOCKET, ATTEMPT'),
#  (470, 12, 'TILL TAP - GRAND THEFT ($950.01 & OVER)'),
#  (349, 12, 'GRAND THEFT / AUTO REPAIR'),
#  (948, 10, 'BIGAMY'),
#  (882, 8, 'INCITING A RIOT'),
#  (830, 8, 'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)'),
#  (445, 7, 'DISHONEST EMPLOYEE ATTEMPTED THEFT'),
#  (952, 3, 'ABORTION/ILLEGAL'),
#  (432, 3, 'BLOCKING DOOR INDUCTION CENTER'),
#  (113, 3, 'MANSLAUGHTER, NEGLIGENT'),
#  (472, 2, 'TILL TAP - ATTEMPT'),
#  (926, 1, 'TRAIN WRECKING'),
#  (453, 1, 'DRUNK ROLL - ATTEMPT')]

# %% [markdown]
# # Task 5:
# Plot Between Victim Age and Sex.
# - Are victims of a particular sex typically older or younger?
# - What is the age range for each sex?

# %%
crime=%sql select*from Crime_analyze_table  ;
data5=pd.DataFrame(crime)
plt.title("Relationship Between Victim Age and Sex.", fontsize=14)
plot =sns.barplot(x="Victim Age",y="Victim Sex", data=data5)


plt.grid()
plt.show()
# Out:
#  * sqlite:///Crime_analyze.db
# Done.
